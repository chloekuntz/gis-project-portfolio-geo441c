# %% [markdown]
# <a href="https://colab.research.google.com/github/chloekuntz/gis-project-portfolio-geo441c/blob/main/basic-mapping/GEO441_541_Week1_Kuntz_Chloe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **GEO 441/541C Week 1 Assignment: Introduction to ArcGIS Pro GUI**

# %% [markdown]
# 🚀 Created by Chloe Kuntz
# 01/30/2026

# %% [markdown]
# ### **Get ready to start**

# %% [markdown]
# ### **Create my first map using ArcGIS Pro**
#
# 1. **Instructions**
#    - Follow mapping instructions from [this Canvas file](PASTE_CANVAS_LINK_HERE)
#    - Mapping instructions are adapted from *Lab 1: Introduction to ArcGIS Pro* in [GIS Fundamentals Resources page](https://www.gisfundamentals.org/resources)
#
# 2. **Share map**
#    - Upload the PNG file exported from ArcGIS Pro to my Google Drive folder for Week 1 assignment
#    - Change Share privilege to make this file viewable by anyone with a link
#    - Copy the sharable link
#
# 3. **Obtain a sharable link**
#
#    - The default link I get for this PNG file is listed below but it cannot be directly used in Notebook to show the picture correctly
# https://drive.google.com/file/d/PASTE_FILE_ID_HERE/view?usp=sharing
#   - I made some changes to the default sharable link:
#     - Keep the **`1A2B3C4D5E6F7G8H9I0J`** part because this is the unique file ID for the picture
#     - Deleted **`/view?usp=sharing`** at the end of the link
#     - Replaced **`/file/d/`** with **`/uc?export=view&id=`**
#    - Here is an example I referred to:
#     - Default sharable link
#
# https://drive.google.com/file/d/1A2B3C4D5E6F7G8H9I0J/view?usp=sharing
#    - The direct link for view from this example would be
#
# https://drive.google.com/uc?export=view&id=1A2B3C4D5E6F7G8H9I0J
#   - The link below is the correct one I need to use in the next section
#
# https://drive.google.com/uc?export=view&id=PASTE_FILE_ID_HERE
#
#
# 4. **Map**
#
#    ![Map](https://drive.google.com/uc?export=view&id=1gUkzGt47uIys-WvvtuBc9nrgoLr-qjOb) <!-- Example Image Placeholder -->

# %% [markdown]
# ### **Reflection on my first experience with ArcGIS Pro**
#
# - Overall, I spent about 2 hours to finish creating my first map
# - Here is a table showing things that I feel excited and challenging in my first experience working in ArcGIS Pro
#
# | Things I'm excited about      | Things challenging for me  |
# | ----------------------------- | -------------------------- |
# | Learning about the different layer types we will use different maps     | Making sure I remember to continually save my progress in ArcGIS  |
# | Getting to put my own spin on design elements such as color, symbol, and font choices     | Making sure I am saving my files to a consistent location I know how to get back to    |
# | Learning a new skill to apply in my future career      | Learning to navigate around ArcGIS and remember where specific tools are   |
#
# - Here is how I rate my first experience working in ArcGIS Pro
#   - Data important and management
#     - This part went well. I have previous experience with zip files and extracting them, so that was easy.  Additionally, I was able to get all my data into ArcGIS with no issues.
#   - Map creation and annotation
#     - This was interesting to me because of the various tabs we had to open, including a map and a layout, to create the map and then annotate it.  I would have assumed it could all be done in one, but I understand how it is useful to make annotations in a separate place that can then be saved and exported, while keeping the plain map on its own.
#   - Navigate the software using its GUI
#     - I am not super comfortable with this yet, since it is completely new to me.  There are a lot of elements and tools that ArcGIS has available, but I am confident that as I practice more I will become more familiar with navigating around the interface.

# %% [markdown]
# ### **Save and share this notebook**
#
# - I made this notebook viewable by anyone with the link
#
# ![Share Notebook](https://drive.google.com/uc?export=view&id=14RwSqMSKCg_9NHbNmEPhqMbPq0OyDJCV)
#
# - Then I copied [this link](https://colab.research.google.com/drive/11jBr_E9b4I1PqcALbUu9W_clRDqxw7Zc?usp=sharing) as my submission to Assignment Week 1

# %% [markdown]
# ### **Reference**
#
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
